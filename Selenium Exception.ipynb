# %%
pip install selenium

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://www.amazon.in/")

Prod=driver.find_element_by_id('twotabsearchtextbox')
Prod.send_keys("Camera")
time.sleep(3)
Search=driver.find_element_by_xpath("//input[@id='nav-search-submit-button']")
Search.click()

Brand=[]
Product=[]
Rating=[]
NRatings=[]
Price=[]
RE=[]
ExpDelivery=[]
Availability=[]
Details=[]
URL=[]

# %%
try:
    BrandName=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']//a[0]//span[0]")
    for i in BrandName[0:21]:
        BN=i.text
        Brand.append(BN)
    print(Brand[0:21])
except NoSuchElementException as e:
    BrandName=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
    for i in BrandName[0:21]:
        BN=i.text
        Brand.append(BN)
    print(Brand[0:21])
    
Prod="-"
for i in Prod[0:21]:
    Product.append(Prod)
Product[0:21]

Ratings=driver.find_elements_by_xpath("//div[@class='a-section a-spacing-none a-spacing-top-micro faceout-product-review']//div//span//span//a//i//span")
for i in Ratings[0:21]:
    Rate=i.text
    Rating.append(Rate)
print(Rating[0:21])

NRating=driver.find_elements_by_xpath("//div[@class='a-section a-spacing-none a-spacing-top-micro faceout-product-review']//div//span//span//a//i//span")
for i in NRating[0:21]:
    NRate=i.text
    NRatings.append(NRate)
print(NRatings[0:21])

Price1=driver.find_elements_by_xpath("//div[@class='sg-col sg-col-4-of-12 sg-col-4-of-16 sg-col-4-of-20']//div//div//div[1]//a//span//span//span[2]")
for i in Price1[0:21]:
    Pr=i.text
    Price.append(Pr)
print(Price[0:21])

ExpD=driver.find_elements_by_xpath("//div[@class='sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20']//div[0]//div[0]//div[2]//div[0]//div[0]//div[1]//div[0]//div[0]//span[1]//span[1]")
for i in ExpD[0:21]:
    Exp=i.text
    ExpDelivery.append(Exp)
print(ExpDelivery[0:21])

Avai="-"
for i in Avai[0:21]:
    Availability.append(Avai)
Availability[0:21]

Det="-"
for i in Det[0:21]:
    Details.append(Det)
Details[0:21]

PURL=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']//a")
for i in PURL[0:21]:
    PURL1=i.get_attribute('href')
    URL.append(PURL1)
print(URL[0:21])

DF1=pd.DataFrame()
DF1["Brand"]=Brand
DF1["Product"]="-"
DF1["Rating"]=Rating
DF1["No Of Rating"]=NRatings
#DF1["Price"]=Price
DF1["Expected Delivery"]=ExpDelivery
DF1["Availability"]=Availability
DF1["Details"]=Details
DF1["URL"]=URL

DF1

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://images.google.com/")

Fruits=driver.find_element_by_xpath("//input[@class='gLFyf gsfi']")
Fruits.send_keys("fruits")
time.sleep(3)
Search=driver.find_element_by_xpath("//button[@type='submit']")
Search.click()

Fruit=[]

#FruitsLink=driver.find_elements_by_xpath("//div[@class='bRMDJf islir']//img")
#for i in FruitsLink[0:100]:
#    Fr=i.get_attribute('src')
#    Fruit.append(Fr)
#Fruit[0:100].screenshot('C:/Users/DELL/Documents/Fruits.png')

for i in range(1,100):
    driver.find_element_by_xpath("//div[@class='bRMDJf islir']//img").screenshot('C:/Users/DELL/Documents/Fruits('+str(i)+').png')

Cars=driver.find_element_by_xpath("//input[@class='og3lId']")
Cars.clear()
Cars.send_keys("Cars")
#time.sleep(3)
Car_search=driver.find_element_by_id('BIqFsb')
Car_search.click()

for i in range(1,100):
    try:
        driver.find_element_by_xpath("//div[@class='bRMDJf islir']//img").screenshot('C:/Users/DELL/Documents/Cars('+str(i)+').png')
    except:
        pass
ML=driver.find_element_by_xpath("//input[@class='og3lId']")
ML.clear()
ML.send_keys("Machine Learning")
#time.sleep(3)
ML_search=driver.find_element_by_id('BIqFsb')
ML_search.click()

for i in range(1,100):
    try:
    driver.find_element_by_xpath("//div[@class='bRMDJf islir']//img").screenshot('C:/Users/DELL/Documents/ML('+str(i)+').png')
    except:
        pass

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://www.flipkart.com/")

Close=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
Close.click()

Phone=driver.find_element_by_xpath("//input[@class='_3704LK']")
Phone.send_keys("Nokia")
time.sleep(3)
Search=driver.find_element_by_xpath("//button[@type='submit']")
Search.click()

# %%
Brand=[]
BrandName=driver.find_elements_by_xpath("//div[@class='_4ddWXP']//a[2]")
for i in BrandName:
    Br=i.text
    Brand.append(Br)
#Brand

Rating=[]
Rate=driver.find_elements_by_xpath("//div[@class='_4ddWXP']//div[2]//span//div")
for i in Rate:
    Rat=i.text
    Rating.append(Rat)
Rating

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://www.forbes.com/billionaires/")

Rank=[]

Ranking=driver.find_elements_by_xpath("//div[@class='rank']")
for i in Ranking:
    R=i.text
    Rank.append(R)
Rank

Name=[]
Person=driver.find_elements_by_xpath("//div[@class='personName']//div")
for i in Person:
    PN=i.text
    Name.append(PN)
Name

NW=[]
Worth=driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
for i in Worth:
    Net=i.text
    result = [x.strip() for x in Net.split(',')]
    NW.append(result)
NW

Age=[]
Age1=driver.find_elements_by_xpath("//div[@class='age']//div[1]")
for i in Age1:
    AgeN=i.text
    Age.append(AgeN)
Age

Country=[]
Coun=driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
for i in Coun:
    Coun1=i.text
    Country.append(Coun1)
Country

Source=[]
Sour=driver.find_elements_by_xpath("//div[@class='source-column']//div[1]")
for i in Sour:
    Sour1=i.text
    Source.append(Sour1)
Source

Industry=[]
Cat=driver.find_elements_by_xpath("//div[@class='category']//div[1]")
for i in Cat:
    Category=i.text
    Industry.append(Category)
Industry

DF=pd.DataFrame()
DF["Rank"]=Rank
DF["Name"]=Name
#DF["Net Worth"]=NW
DF["Age"]=Age
DF["Country"]=Country
DF["Source"]=Source
DF["Industry"]=Industry

DF

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://www.digit.in/")

Lap=driver.find_element_by_link_text("LAPTOPS").click()

Best_Laptop=driver.find_element_by_link_text("Best Gaming Laptops in India").click()

Product=[]

Prod=driver.find_elements_by_xpath("//table[@id='summtable']//tbody//tr//td[1]")
for i in Prod:
    Prd=i.text
    Product.append(Prd)
Product

OS=[]

OS1=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[3]//td[3]")
for i in OS1:
    OS2=i.text
    OS.append(OS2)
OS

Display=[]

Disp=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[4]//td[3]")
for i in Disp:
    Disp1=i.text
    Display.append(Disp1)      
Display

Processor=[]

Proc=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[5]//td[3]")
for i in Proc:
    Proc1=i.text
    Processor.append(Proc1)      
Processor

Memory=[]

Mem=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[5]//td[3]")
for i in Mem:
    Mem1=i.text
    Memory.append(Mem1)      
Memory

Weight=[]
Wei=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[6]//td[3]")
for i in Wei:
    Wei1=i.text
    Weight.append(Wei1)      
Weight

Dimension=[]
Dim=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[7]//td[3]")
for i in Dim:
    Dim1=i.text
    Dimension.append(Wei1)      
Dimension

Graphic=[]
GP=driver.find_elements_by_xpath("//div[@class='Spcs-details']//tbody//tr[8]//td[3]")
for i in GP:
    GP1=i.text
    Graphic.append(GP1)      
Graphic

Price=[]

Pr=driver.find_elements_by_xpath("//table[@id='summtable']//tbody//tr//td[3]")
for i in Pr:
    Pr1=i.text
    Price.append(Pr1)
Price

Seller=[]

SL=driver.find_elements_by_xpath("//table[@id='summtable']//tbody//tr//td[2]")
for i in SL:
    SL1=i.text
    Seller.append(SL1)
Seller

DF=pd.DataFrame()
DF["Product"]=Product
DF["OS"]=OS
DF["Display"]=Display
DF["Processor"]=Processor
DF["Memory"]=Memory
DF["Weight"]=Weight
DF["Dimension"]=Dimension
DF["Graphic Processor"]=Graphic
DF["Price"]=Price
DF["Seller"]=Seller

DF

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://www.youtube.com/watch?v=fn2F6-m9g3w")


Comment=[]
Comm=driver.find_elements_by_xpath("//div[@id='content']//yt-formatted-string")
for i in Comm[1:500]:
    Comment1=i.text
    Comment.append(Comment1)
Comment[1:500]

Upvote=[]
Up=driver.find_elements_by_xpath("//span[@id='vote-count-middle']")
for i in Up[1:500]:
    Up1=i.text
    Upvote.append(Up1)
Upvote[1:500]

Time=[]
Time1=driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']//a[1]")
for i in Time1[1:500]:
    Time2=Time1.text
    Time.append(Time2)
Time[1:500]

DF=pd.DataFrame()
DF["Comments"]=Comments
DF["UpVote"]=Upvote
DF["Time"]=Time

DF

# %%
import selenium
import pandas as pd
import warnings
import time
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\DELL\Documents\chromedriver.exe")

driver.get("https://www.hostelworld.com/")

Search=driver.find_elements_by_id('search-input-field')
Search.send_keys("London")

Button=

HName=[]
Name=driver.find_elements_by_xpath("//div[@class='property-card']//div[2]//div//h2//a")
for i in Name:
    HN=i.text
    HName.append(HN)
HName

Distance=[]

Dist=driver.find_elements_by_xpath("//div[@class='property-card']//div[2]//div[2]//1//span")
for i in Dist:
    Dist1=i.text
    Distance.append(Dist1)
Distance

Private=[]
Priv=driver.find_elements_by_xpath("//div[@class='prices-col']//div//a//div//div")
for i in Priv:
    Priv1=i.text
    Private.append(Priv1)
Private

Dorms=[]
Dorm=driver.find_elements_by_xpath("//div[@class='prices-col']//div//a//div//div")
for i in Dorm:
    Dorm1=i.text
    Dorms.append(Dorm1)
Dorms

Ratings=[]
Rate=driver.find_elements_by_xpath("//div[@class='rating rating-summary-container big']//div[1]")
for i in Rate:
    R=i.text
    Ratings.append(R)
Ratings

NRatings=[]
NRate=driver.find_elements_by_xpath("//div[@class='reviews']")
for i in NRate:
    NR=i.text
    NRatings.append(NR)
NRatings

DF=pd.DataFrame()
DF["Name"]=HNmae
DF["Distance"]=Distance
DF["Private"]=Private
DF["Dorms Price"]=Dorms
DF["Ratings"]=Ratings
DF["No of Ratings"]=NRatings

DF
