# %%
pip install selenium

# %%
import selenium
import pandas as pd
import warnings
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.naukrigulf.com/")

search=driver.find_element_by_xpath("//div[@class='qsb-proxy']/button")
search.click()

# %%
Search_job=driver.find_element_by_id('qsbKey')
Search_job.send_keys("Data Analyst")
#driver.manage().timeouts().implicitlyWait(50, TimeUnit.SECONDS);
#Thread.sleep(1)
Search_Loc=driver.find_element_by_xpath("//input[@class='ng-inp-lg input-group float-droope-input']")
Search_Loc.send_keys("Dubai")

Search_btn=driver.find_element_by_xpath("//input[@type='submit']")
Search_btn.click()
#url='https://www.naukrigulf.com/data-analyst-jobs-in-dubai?recentSearch=false&requestsource=mr&titles=2591&ts=1636209532000&xz=1_25_5'
#driver.get(url)

    
#Loc=driver.find_elements_by_xpath("//li[@class='info-loc has-logo']/span")
#Loc[0:10]

#for i in Loc:
 #   JLoc=i.text
  #  Location.append(JLoc)
#Location[0:10]
    
#DF=pd.DataFrame()
#DF["TITLE"]=jobtitle1
#DF["LOCATION"]=Location

#DF

# %%
#driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")
#url='https://www.naukrigulf.com/data-analyst-jobs-in-dubai?recentSearch=false&requestsource=mr&titles=2591&ts=1636209532000&xz=1_25_5'
#driver.get(url)


#Thread.sleep(1)

#Title

jobtitle1=[]

Title=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//a//h2[1]")
Title[0:10]

for i in Title:
    JTitle=i.text
    jobtitle1.append(JTitle)
jobtitle1[0:10]


#Location

Location=[]
Loc=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//li[2]//span[2]")
Loc[0:10]

for j in Loc:
    JLoc=j.text
    Location.append(JLoc)
Location[0:10]


#Company

Company=[]

Comp=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//p[1]")
Comp[0:10]

for k in Comp:
    JComp=k.text
    Company.append(JComp)
Company[0:10]

#Experience

Experience=[]

#Thread.sleep(1)

Exp=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//li[1]//span[2]")
Exp[0:10]

for l in Exp:
    JExp=l.text
    Experience.append(JExp)
Experience[0:10]


DF=pd.DataFrame()
DF["TITLE"]=jobtitle1
DF["LOCATION"]=Location
DF["COMPANY"]=Company
DF["EXP"]=Experience

DF

# %%
import selenium
import pandas as pd
import warnings
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.naukrigulf.com/")

search=driver.find_element_by_xpath("//div[@class='qsb-proxy']/button")
search.click()

Search_job=driver.find_element_by_id('qsbKey')
Search_job.send_keys("Data Scientist")
#driver.manage().timeouts().implicitlyWait(50, TimeUnit.SECONDS);

#Thread.sleep(1)
Search_Loc=driver.find_element_by_xpath("//input[@class='ng-inp-lg input-group float-droope-input']")
Search_Loc.send_keys("Dubai")

Search_btn=driver.find_element_by_xpath("//input[@type='submit']")
Search_btn.click()

# %%
jobtitle1=[]

Title=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//a//h2[1]")
Title[0:10]

for i in Title[0:10]:
    JTitle=i.text
    jobtitle1.append(JTitle)
jobtitle1[0:10]


#Location

Location=[]
Loc=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//li[2]//span[2]")
Loc[0:10]

for j in Loc[0:10]:
    JLoc=j.text
    Location.append(JLoc)
Location[0:10]


#Company

Company=[]

Comp=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//p[1]")
Comp[0:10]

for k in Comp[0:10]:
    JComp=k.text
    Company.append(JComp)
Company[0:10]

#Experience

Experience=[]

#Thread.sleep(1)




DF=pd.DataFrame()
DF["TITLE"]=jobtitle1
DF["LOCATION"]=Location
DF["COMPANY"]=Company


DF

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.naukrigulf.com/")

search=driver.find_element_by_xpath("//div[@class='qsb-proxy']/button")
search.click()

Search_job=driver.find_element_by_id('qsbKey')
Search_job.send_keys("Data Scientist")
#driver.manage().timeouts().implicitlyWait(50, TimeUnit.SECONDS);

time.sleep(1)
#Search_Loc=driver.find_element_by_xpath("//input[@class='ng-inp-lg input-group float-droope-input']")
#Search_Loc.send_keys("Dubai")

Search_btn=driver.find_element_by_xpath("//input[@type='submit']")
Search_btn.click()

# %%
time.sleep(1)
#Loc_Filter=driver.find_elements_by_xpath("//ul[@class='check-aria']//li//label//span[2]")
Loc_Filter=driver.find_elements_by_xpath("//ul[@class='check-aria']//li//label//span[2]")
for i in Loc_Filter:
    if i.text=='Dubai(1966)':
        i.click()
        break
        

time.sleep(1)
Sal_Filter=driver.find_elements_by_xpath("//ul[@class='check-aria']//li//label//span[2]")
for i in Sal_Filter:
    if i.text=='$1001 - $2000(202)':
        i.click()
        break
time.sleep(1)
RefSearch_btn=driver.find_element_by_xpath("//button[@class='ng-btn blue refine fxd display-true']")
RefSearch_btn.click()

# %%
jobtitle1=[]

Title=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//a//h2[1]")
Title[0:10]

for i in Title[0:10]:
    JTitle=i.text
    jobtitle1.append(JTitle)
jobtitle1[0:10]


#Location

Location=[]
Loc=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//li[2]//span[2]")
Loc[0:10]

for j in Loc[0:10]:
    JLoc=j.text
    Location.append(JLoc)
Location[0:10]


#Company

Company=[]

Comp=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//p[1]")
Comp[0:10]

for k in Comp[0:10]:
    JComp=k.text
    Company.append(JComp)
Company[0:10]

#Experience

Experience=[]

#Thread.sleep(1)

Exp=driver.find_elements_by_xpath("//div[@class='ng-box srp-tuple']//li[1]//span[2]")
Exp[0:10]

for l in Exp[0:10]:
    JExp=l.text
    Experience.append(JExp)
Experience[0:10]


DF=pd.DataFrame()
DF["TITLE"]=jobtitle1
DF["LOCATION"]=Location
DF["COMPANY"]=Company
DF["EXP"]=Experience

DF

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.flipkart.com/")

Close_btn=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
Close_btn.click()

time.sleep(5)

Search_job=driver.find_element_by_xpath("//input[@class='_3704LK']")
Search_job.send_keys("Sunglasses")

# %%
time.sleep(1)

Search_btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
Search_btn.click()

BrandName=[]
Description=[]
Price=[]
Discount=[]

time.sleep(1)
#Brand=driver.find_elements_by_xpath("div[@class='_2B099V']//div")

Brand=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")

for i in Brand[0:40]:
    Brnd=i.text
    BrandName.append(Brnd)
    #print(BrandName)
    
Desc=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

for i in Desc[0:40]:
    Desc1=i.text
    Description.append(Desc1)
   # print(Description)
    
Price_data=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[1]")

for i in Price_data[0:40]:
    PriceD=i.text
    Price.append(PriceD)
    #print(Price)
    
Disc=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[3]")


for i in Disc[0:40]:
    Discper=i.text
    Discount.append(Discper)
   # print(Discount)
    
    
DF=pd.DataFrame()
DF["Brand Name"]=BrandName
DF["Description"]=Description
DF["Price"]=Price
DF["Discount%"]=Discount

DF

# %%
#Nxt=driver.find_elements_by_xpath("//a[@class='_1LKTO3']".get_attribute('href'))
Nxt=driver.find_element_by_partial_link_text("NEXT")
Nxt.click()

BrandName1=[]
Description1=[]
Price1=[]
Discount1=[]

#Brand=driver.find_elements_by_xpath("div[@class='_2B099V']//div")

time.sleep(1)

Brand1=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")

for i in Brand1[0:40]:
    Brnd1=i.text
    BrandName1.append(Brnd1)
    #print(BrandName)
    
Desc2=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

for i in Desc2[0:40]:
    Desc3=i.text
    Description1.append(Desc3)
   # print(Description)
    
Price_data1=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[1]")

for i in Price_data1[0:40]:
    PriceD1=i.text
    Price1.append(PriceD1)
    #print(Price)
    
Disc1=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[3]")


for i in Disc1[0:40]:
    Discper1=i.text
    Discount1.append(Discper1)
   # print(Discount)
    
    
DF1=pd.DataFrame()
DF1["Brand Name"]=BrandName1
DF1["Description"]=Description1
DF1["Price"]=Price1
DF1["Discount%"]=Discount1

time.sleep(1)

Nxt1=driver.find_element_by_partial_link_text("NEXT")
Nxt1.click()

time.sleep(1)

BrandName2=[]
Description2=[]
Price2=[]
Discount2=[]

#Brand=driver.find_elements_by_xpath("div[@class='_2B099V']//div")

time.sleep(1)

Brand2=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")

for i in Brand2[0:40]:
    Brnd2=i.text
    BrandName2.append(Brnd2)
    #print(BrandName)
    
Desc4=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

for i in Desc4[0:40]:
    Desc5=i.text
    Description2.append(Desc5)
   # print(Description)
    
Price_data2=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[1]")

for i in Price_data2[0:40]:
    PriceD2=i.text
    Price2.append(PriceD2)
    #print(Price)
    
Disc2=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[3]")


for i in Disc2[0:40]:
    Discper2=i.text
    Discount2.append(Discper2)
   # print(Discount)
    
    
DF2=pd.DataFrame()
DF2["Brand Name"]=BrandName2
DF2["Description"]=Description2
DF2["Price"]=Price2
DF2["Discount%"]=Discount2




#DF3=pd.DataFrame()

list1=[DF,DF1,DF2]
DF3=pd.concat(list1)
DF3

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-%20earpods-power%02adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKC%20TSVZAXUHGREPBFGI&marketplace.")

time.sleep(5)

RR_All=driver.find_element_by_partial_link_text("All 5830 reviews")
RR_All.click()

#url=driver.find_elements_by_xpath("//nav[@class='yFHi8N']//a[0:10]")

time.sleep(2)
Rating=[]
Summary=[]
RatingP=[]

time.sleep(2)

for i in range(0,11):
    #Ratings=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    Ratings=driver.find_elements_by_xpath("//div[@class='col _2wzgFH K0kLPL']//div[1]//div")
    for j in Ratings[0:100]:
        Rate=j.text
        Rating.append(Rate)
        Rating[0:100] 
        time.sleep(2)

    RatingsP=driver.find_elements_by_xpath("//div[@class='_3LWZlK _1rdVr6 _1BLPMq']")
    for l in RatingsP[0:100]:
        RateP=l.text
        RatingP.append(RateP)
        time.sleep(2)
        RatingP[0:100] 
    #Summ=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
    Summ=driver.find_elements_by_xpath("//p[@class='_2-N8zT']")
    for k in Summ[0:100]:
        Summ1=k.text
        Summary.append(Summ1)
        time.sleep(2)
        Summary[0:100]    
    Nxt=driver.find_element_by_partial_link_text("NEXT")
    Nxt.click()
#print(Ratings)


#for j in Ratings:
  #  Rate=j.text
   # Rating.append(Rate)
#    time.sleep(2)

#DF=pd.DataFrame()
#DF["Ratings"]=Rating
#DF["Summary"]=Summary

#DF

#print(Rating)
#print(Summary)

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.flipkart.com/")

Close_btn=driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
Close_btn.click()

time.sleep(5)

Search_job=driver.find_element_by_xpath("//input[@class='_3704LK']")
Search_job.send_keys("Sneakers")

time.sleep(1)

Search_btn=driver.find_element_by_xpath("//button[@class='L0Z3Pu']")
Search_btn.click()

BrandName=[]
Description=[]
Price=[]
Discount=[]


time.sleep(1)
#Brand=driver.find_elements_by_xpath("div[@class='_2B099V']//div")

Brand=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")

for i in Brand[0:40]:
    Brnd=i.text
    BrandName.append(Brnd)
    #print(BrandName)
    
Desc=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

for i in Desc[0:40]:
    Desc1=i.text
    Description.append(Desc1)
   # print(Description)
    
Price_data=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[1]")

for i in Price_data[0:40]:
    PriceD=i.text
    Price.append(PriceD)
    #print(Price)
    
Disc=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[3]")


for i in Disc[0:40]:
    Discper=i.text
    Discount.append(Discper)
   # print(Discount)
    
    
DF=pd.DataFrame()
DF["Brand Name"]=BrandName
DF["Description"]=Description
DF["Price"]=Price
DF["Discount%"]=Discount

DF

# %%
time.sleep(3)

Nxt=driver.find_element_by_partial_link_text("NEXT")
Nxt.click()

BrandName1=[]
Description1=[]
Price1=[]
Discount1=[]

#Brand=driver.find_elements_by_xpath("div[@class='_2B099V']//div")

time.sleep(1)

Brand1=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")

for i in Brand1[0:40]:
    time.sleep(5)
    #wait.until(ExpectedConditions.stalenessOf("Brand1"));
    Brnd1=i.text
    BrandName1.append(Brnd1)
    #print(BrandName)
    
Desc2=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

for i in Desc2[0:40]:
    Desc3=i.text
    Description1.append(Desc3)
    print(Description)
    
Price_data1=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[1]")

for i in Price_data1[0:40]:
    PriceD1=i.text
    Price1.append(PriceD1)
    #print(Price)
    
Disc1=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[3]")


for i in Disc1[0:40]:
    Discper1=i.text
    Discount1.append(Discper1)
   # print(Discount)
    
    
DF1=pd.DataFrame()
DF1["Brand Name"]=BrandName1
DF1["Description"]=Description1
DF1["Price"]=Price1
DF1["Discount%"]=Discount1

time.sleep(1)

Nxt1=driver.find_element_by_partial_link_text("NEXT")
Nxt1.click()

time.sleep(1)

BrandName2=[]
Description2=[]
Price2=[]
Discount2=[]

#Brand=driver.find_elements_by_xpath("div[@class='_2B099V']//div")

time.sleep(1)

Brand2=driver.find_elements_by_xpath("//div[@class='_2WkVRV']")

for i in Brand2[0:40]:
    Brnd2=i.text
    BrandName2.append(Brnd2)
    #print(BrandName)
    
Desc4=driver.find_elements_by_xpath("//a[@class='IRpwTa']")

for i in Desc4[0:40]:
    Desc5=i.text
    Description2.append(Desc5)
   # print(Description)
    
Price_data2=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[1]")

for i in Price_data2[0:40]:
    PriceD2=i.text
    Price2.append(PriceD2)
    #print(Price)
    
Disc2=driver.find_elements_by_xpath("//a[@class='_3bPFwb']//div//div[3]")


for i in Disc2[0:40]:
    Discper2=i.text
    Discount2.append(Discper2)
   # print(Discount)
    
    
DF2=pd.DataFrame()
DF2["Brand Name"]=BrandName2
DF2["Description"]=Description2
DF2["Price"]=Price2
DF2["Discount%"]=Discount2




#DF3=pd.DataFrame()

list1=[DF,DF1,DF2]
DF3=pd.concat(list1)
DF3

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.amazon.in/")

time.sleep(5)

srch=driver.find_element_by_id("twotabsearchtextbox")
srch.send_keys("Laptops")

time.sleep(3)

Button=driver.find_element_by_id("nav-search-submit-button")
Button.click()

# %%
Filter1=driver.find_elements_by_xpath("//a[@class='a-link-normal s-navigation-item']/span")
for i in Filter1:
    if i.text=='Intel Core i7':
        i.click()
        break


Filter1=driver.find_elements_by_xpath("//a[@class='a-link-normal s-navigation-item']/span")
for i in Filter1:
    if i.text=='Intel Core i9':
        i.click()
        break
        
#for i in range(3):
 #   time.sleep(2)
  #  try:
   #     driver.find_element_by_xpath("//ul[@class='a-pagination']/li[8]").click()
    #except:
     #   driver.find_element_by_xpath("//ul[@class='a-pagination']/li[7]").click()

LaptopTitle=[]
LaptopPrice=[]

Tit=driver.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']//a//span")
Tit[0:10]
for i in Tit[0:10]:
    Title=i.text
    LaptopTitle.append(Title)
#print(LaptopTitle[0:10])

PR=driver.find_elements_by_xpath("//span[@class='a-price']//span//span[2]")
PR[0:10]
for i in PR[0:10]:
    Price=i.text
    LaptopPrice.append(Price)
#print(LaptopPrice[0:10])

DF=pd.DataFrame()
DF["Laptop Title"]=LaptopTitle
DF["Laptop Price"]=LaptopPrice
DF

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.ambitionbox.com/")

job_link=driver.find_element_by_xpath("//a[@class='link jobs']")
job_link.click()

Search_tags=driver.find_element_by_xpath("//input[@class='input tt-input']")
Search_tags.send_keys("Data Scientist")

time.sleep(3)

Search_Button=driver.find_element_by_xpath("//span[@class='ctas-btn-medium']")
Search_Button.click()


time.sleep(3)

Location=driver.find_element_by_xpath("//div[@title='Location']//i")
Location.click()


time.sleep(3)

Locsel=driver.find_element_by_xpath("//label[@for='location_Noida']")
Locsel.click()


time.sleep(3)

Company=[]
Experience=[]

Comp=driver.find_elements_by_xpath("//div[@itemprop='itemListElement']//div[2]//div[1]//p[1]")
Comp[0:10]
for i in Comp[0:10]:
    comp=i.text
    Company.append(comp)
#    print(Company[0:10])

Exp=driver.find_elements_by_xpath("//div[@itemprop='itemListElement']//div[3]//div[1]//div[1]//p[1]")
Exp[0:10]
for i in Exp[0:10]:
    exp=i.text
    Experience.append(exp)
#print(Experience[0:10])


DF=pd.DataFrame()
DF["Company"]=Company
DF["Experience"]=Experience
DF

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.webdriver.common.keys import Keys

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.ambitionbox.com/")

time.sleep(3)

Salary_link=driver.find_element_by_xpath("//a[@class='link salaries']")
Salary_link.click()

Search_tags=driver.find_element_by_id("jobProfileSearchbox")
Search_tags.send_keys("Data Scientist")

#driver.findElement(By.id("jobProfileSearchbox")).send_keys(Keys.ENTER)

#Search_tags1=driver.find_element_by_id("jobProfileSearchbox")
#Search_tags1.send_keys(Keys.ENTER)

Role=select(driver.find_elements_by_xpath("//div[@class='tt-dataset tt-dataset-job-profile-search']//div[1]//div[1]//div[1]//div[1]//p"))
Role.click()      

        



#Search_Button=driver.find_element_by_xpath("//span[@class='ctas-btn-medium']")
#Search_Button.click()


#time.sleep(3)

#Location=driver.find_element_by_xpath("//div[@title='Location']//i")
#Location.click()


#time.sleep(3)

#Locsel=driver.find_element_by_xpath("//label[@for='location_Noida']")
#Locsel.click()


#time.sleep(3)

# %%
time.sleep(3)

Company=[]
Role=[]
Minsalary=[]
Salary=[]
Maxsalary=[]

Comp=driver.find_elements_by_xpath("//div[@class='result-row']//div[1]//div[2]//div[1]//a")
Comp[0:10]

for i in Comp[0:10]:
    C=i.text
    Company.append(C)
print(Company[0:10])

Rol=driver.find_elements_by_xpath("//div[@class='salaries sbold-list-header']")
Rol[0:10]
for i in Rol[0:10]:
    R=i.text
    Role.append(R)
print(Role[0:10])

Min=driver.find_elements_by_xpath("//div[@class='result-col salary-range']//div[1]//div[2]//div[1]")
Min[0:10]
for i in Min[0:10]:
    MinSal=i.text
    Minsalary.append(MinSal)
print(Minsalary[0:10])


Max=driver.find_elements_by_xpath("//div[@class='result-col salary-range']//div[1]//div[2]//div[2]")
Max[0:10]
for i in Max[0:10]:
    MaxSal=i.text
    Maxsalary.append(MaxSal)
print(Maxsalary[0:10])

Sal=driver.find_elements_by_xpath("//div[@class='result-col salary-range']//div[1]//div[1]//div[1]//p")
Sal[0:10]
for i in Sal[0:10]:
    SalM=i.text
    Salary.append(SalM)
print(Salary[0:10])

DF=pd.DataFrame()
DF["Company"]=Company
DF["Role"]=Role
DF["Min Salary"]=Minsalary
DF["Salary"]=Salary
DF["Max Salary"]=Maxsalary

DF

# %%
import selenium
import pandas as pd
import time
import warnings 
from selenium import webdriver
from selenium.common.exceptions import InvalidSessionIdException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support.expected_conditions import presence_of_element_located
from selenium.webdriver.common.keys import Keys

driver=webdriver.Chrome(r"C:\Users\Pradeep\Downloads\chromedriver_win32\chromedriver.exe")

driver.get("https://www.myntra.com/shoes")

time.sleep(3)

Filter1=driver.find_elements_by_xpath("//ul[@value='7142.0 TO 14095.0']")
Filter1.click()
break


Filter1=driver.find_elements_by_xpath("//li[@value='Black']")
Filter1.click()
break
