# %%
import io
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
Data=pd.read_csv("C:/Users/Pradeep/OneDrive/Documents/customer Retention.csv")

# %%
Data.shape
# Out:
# (269, 71)

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
Data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
Data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
Data.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
Data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#Data.head(299)
DF=pd.DataFrame(Data)
DF
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
DF["Frequent Buyers"]= [ "Frequent Buyers" if x>=3 else "Rare Buyers" for x in DF[6 How many times you have made an online purchase in the past 1 year? ]]
# Out:
#   File "<ipython-input-21-a4b8deded6b2>", line 1
#     DF["Frequent Buyers"]= [ "Frequent Buyers" if x>=3 else "Rare Buyers" for x in DF[6 How many times you have made an online purchase in the past 1 year? ]]
#                                                                                         ^
# SyntaxError: invalid syntax

# %%
DF=Data.iloc[:,:-24]
DF
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
sns.countplot(DF["1Gender of respondent"])
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %% [markdown]
# From the above graph we come to know Females use more online shopping sites than Male

# %%
sns.countplot(DF["2 How old are you? "])
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %% [markdown]
# The above graph shows that people in age group 21 to 50 years are the ones who use online shopping more than the other ages

# %%
plt.figure(figsize=(15,4))
sns.countplot(DF["3 Which city do you shop online from?"])
plt.show()
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Most of the reviewsare from the major cities like Noida, Bangalore,Delhi, Karnal , solan and Ghaziabad

# %%
sns.countplot(DF["12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   "])
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ', ylabel='count'>

# %% [markdown]
# We could see that most of the people came to know about the online shopping platform through search engine while surfing other details on internet. Content Marketing and Dusplay Adverts have played less role in advertising about the online shopping sites

# %%
sns.countplot(DF["13 After first visit, how do you reach the online retail store?				                                                   "])
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ', ylabel='count'>
# C:\Users\Pradeep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Pradeep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# From the above we come to know that after their first visit Many have downloaded Applications and direct URL's to reach to the sites

# %%
sns.countplot(DF["15 What is your preferred payment Option?					                                                                                                                               "])
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ', ylabel='count'>
# C:\Users\Pradeep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Pradeep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# From the data we could see that most of them prefer to pay using Credit/debit cards

# %%
plt.figure(figsize=(15,4))
sns.countplot(DF["17 Why did you abandon the “Bag”, “Shopping Cart”?					                                                                                                                                                       "])
plt.show()
# Out:
# C:\Users\Pradeep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Pradeep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Pradeep\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
Data2=Data.iloc[:,48:72]
Data2
# Out:
#                     Easy to use website or application  \
# 0                                            Paytm.com
# 1    Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# 4    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ..                                                 ...
# 264                                          Amazon.in
# 265                                       Flipkart.com
# 266                                          Amazon.in
# 267  Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com
# 268                                          Amazon.in
#
#                       Visual appealing web-page layout  \
# 0                                         Flipkart.com
# 1                                Amazon.in, Myntra.com
# 2                     Amazon.in, Paytm.com, Myntra.com
# 3    Amazon.in, Flipkart.com, Paytm.com, Myntra.com...
# ...

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Easy to use website or application"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Visual appealing web-page layout"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Wild variety of product on offer"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Complete, relevant description information of products"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Fast loading website speed of website and application"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Reliability of the website or application"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Quickness to complete purchase"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Availability of several payment options"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Speedy order delivery "])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Privacy of customers’ information"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Security of customer financial information"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Perceived Trustworthiness"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Presence of online assistance through multi-channel"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Longer time to get logged in (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Longer time in displaying graphics and photos (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Late declaration of price (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Longer page loading time (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Limited mode of payment on most products (promotion, sales period)"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Longer delivery period"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Change in website/Application design"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Frequent disruption when moving from one page to another"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Website is as efficient as before"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(y=Data2["Which of the Indian online retailer would you recommend to a friend?"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["18 The content on the website must be easy to read and understand"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["19 Information on similar product to the one highlighted  is important for product comparison"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["20 Complete information on listed seller and product being offered is important for purchase decision."])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["21 All relevant information on listed products must be stated clearly"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["22 Ease of navigation in website"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["23 Loading and processing speed"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["24 User friendly Interface of the website"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["25 Convenient Payment methods"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["27 Empathy (readiness to assist with queries) towards the customers"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["28 Being able to guarantee the privacy of the customer"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["30 Online shopping gives monetary benefit and discounts"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["31 Enjoyment is derived from shopping online"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["32 Shopping online is convenient and flexible"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["33 Return and replacement policy of the e-tailer is important for purchase decision"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["34 Gaining access to loyalty programs is a benefit of shopping online"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["35 Displaying quality Information on the website improves satisfaction of customers"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["36 User derive satisfaction while shopping on a good quality website or application"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["37 Net Benefit derived from shopping online can lead to users satisfaction"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["38 User satisfaction cannot exist without trust"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["39 Offering a wide variety of listed product in several category"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["40 Provision of complete and relevant product information"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["41 Monetary savings"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["42 The Convenience of patronizing the online retailer"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["43 Shopping on the website gives you the sense of adventure"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["44 Shopping on your preferred e-tailer enhances your social status"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["45 You feel gratification shopping on your favorite e-tailer"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["46 Shopping on the website helps you fulfill certain roles"])
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=Data["47 Getting value for money spent"])
plt.show()
